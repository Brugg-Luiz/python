# %% [markdown]
# <a href="https://colab.research.google.com/github/Brugg-Luiz/python/blob/main/aula_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** ✈ ⏰ ⚓

# %%
print("I competição de programação dá Start")
ano = "IX"
print(ano, "competição de programação da Start")
print(f"{ano} competição de programação da Start")
# Out:
# I competição de programação dá Start
# IX competição de programação da Start
# IX competição de programação da Start

# %% [markdown]
# #**Aula 2** ◀ ♒ ▶

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
# Out:
# Os pontos totais do Rodrigo são 24

# %% [markdown]
# #**Aula 3** ✅ 😔 🏎

# %%
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
numero_de_professores = 8
if numero_de_alunos + numero_de_monitores + numero_de_professores <= 50:
  resposta_positiva = "pode ir"
resposta_negativa = "não pode ir"
if numero_de_alunos + numero_de_monitores + numero_de_professores <= 50:
  print(resposta_positiva)
else:
  print(resposta_negativa)
# Out:
# Digite a quantidade de alunos: 35
# Digite a quantidade de monitores: 5
# pode ir

# %% [markdown]
# #**Aula 4**  🥎 🔗 🖐

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 0
# B

# %% [markdown]
# #**Aula 5** 📷 🚵 🆕

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %% [markdown]
# #**Aula 6** 🤣 💧 🤓

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 95
# Digite sua altura (em metros): 2
#
# Seu IMC é: 23.75
# Você está no peso ideal.

# %% [markdown]
# #**Aula 7** 🎃 ⁉ 🐖

# %%
print ("sou seu assistente virtual, como posso ajudar? \n ")
nome = input("Digite seu nome: ")
print("Olá, " + nome +", Qual é a sua dúvida hoje?")
# Out:
# sou seu assistente virtual, como posso ajudar?
#
# Digite seu nome: Luiz
# Olá, Luiz, Qual é a sua dubida hoje?

# %%
print ("sou seu assistente virtual, como posso ajudar? \n ")
nome = input("Digite seu nome: ")
print(f"Olá, {nome}. Qual é a sua dúvida hoje?")
resposta = input("Qual o assunto que deseja tratar: matematica, python, javascript ").lower()
if resposta == "python" :
 print(f"Que bom, {nome}, vamos falar sobre Python. Python é uma linguagem de programação de alto nível, versátil e de código aberto, criada por Guido van Rossum em 1991.")
elif resposta == "javascript" :
 print(f"Que bom, {nome}, vamos falar sobre Javascript. Ele é uma linguagem de programação versátil e dinâmica, usada para criar interatividade e funcionalidades complexas em páginas web.")
elif resposta == "matematica"
 print(f"Que bom, {nome}, vamos falar sobre Matemática. Originalmente do grego, a palavra significa: tudo o que se pode aprender ou conhecer. ")
else:
 print("Me desculpe, não sei tratar sobre esse assunto.")
# Out:
# sou seu assistente virtual, como posso ajudar?
#
# Digite seu nome: Luiz
# Olá, Luiz. Qual é a sua dúvida hoje?
# Qual o assunto que deseja tratar: matematica, python, javascript Matematica
# Que bom, Luiz, vamos falar sobre Matemática. Originalmente do grego, a palavra significa: tudo o que se pode aprender ou conhecer.

# %% [markdown]
# #**Aula 8** 🐞 🚀 🐒

# %%
import random
dicas_do_dia = ["👋 Comece o dia com gratidão e intenção.",
                "😊 Cuide do seu corpo como a casa da sua alma.",
                "📝 Planeje o dia com propósito, não com pressa.",
                "🚴‍♂️ Movimente-se para libertar energia e emoções.",
                "😁 Faça pausas que alimentem a alma.",
                "💡 Viva com presença, não no automático.",
                "🌇 Feche o dia com gentileza e reconciliação."
  ]

while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()

  if pedido == "dica":
    dica = random.choice(dicas_do_dia) # escolhe uma dica aleatóriasair
    print(f"Dica: {dica} \n")
  elif pedido == "sair":
    print("Até a próxima! \n")
    break
  else:
    print("Comando inválido. Tente novamente. \n")
    break
# Out:
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# Dica: 👋 Comece o dia com gratidão e intenção.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-965832703.py in <cell line: 0>()
#      10
#      11 while True:
# ---> 12   pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()
#      13
#      14   if pedido == "dica":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...
